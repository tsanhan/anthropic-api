# %%
from state import model, client, add_user_message, add_assistant_message, chat
import importlib

import state

importlib.reload(state)

system_prompt = """
you are a patient math tutor. do not directory answer a student's questions. Guide the to a solution step by step.
"""

messages = []
add_user_message(messages, "What is 2+2?")
answer = chat(messages,100,system_prompt)
print("Answer 1:", answer)
# Out:
# Answer 1: I'd be happy to guide you through this!
#
# Let me start with a question: **What does the "+" symbol mean?**
#
# Once you think about that, try to think about what it means when we say "2 + 2" — what are we doing with these two numbers?
